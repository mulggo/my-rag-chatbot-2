# %% [markdown]
# # AWS 리소스 설정
#
# 멀티모달 RAG 챗봇에 필요한 AWS 리소스들을 생성하고 설정합니다.
#
# ## 📋 생성할 리소스들
# 1. S3 버킷 (문서 저장용)
# 2. OpenSearch Serverless 컬렉션
# 3. Bedrock Knowledge Base
# 4. IAM 역할 및 정책
#
# **⚠️ 주의**: 이 과정에서 AWS 비용이 발생할 수 있습니다.

# %% [markdown]
# ## 1. 환경 설정 및 확인

# %%
# 가상환경 생성
# !python3 -m venv my-rag-venv
# !my-rag-venv/bin/pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in ./my-rag-venv/lib/python3.9/site-packages (25.2)

# %%
#requirements.txt 파일 설치
# !pip3 install --upgrade pip
# !pip3 install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/ec2-user/.local/lib/python3.9/site-packages (25.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit>=1.39.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.48.0)
# Requirement already satisfied: streamlit-chat>=0.1.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: boto3>=1.35.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.40.6)
# Requirement already satisfied: python-dotenv>=1.0.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.11.7)
# Requirement already satisfied: pypdf>=4.3.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (6.0.0)
# Requirement already satisfied: unstructured in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.18.3)
# Requirement already satisfied: unstructured-inference>=0.7.23 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.7.23)
# Requirement already satisfied: Pillow>=10.4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (11.3.0)
# Requirement already satisfied: pdf2image in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.17.0)
# Requirement already satisfied: opencv-python>=4.10.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (4.12.0.88)
# Requirement already satisfied: pytesseract>=0.3.10 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.3.13)
# Requirement already satisfied: opensearch-py>=2.7.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (3.0.0)
# Requirement already satisfied: opensearch_dsl>=2.1.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (2.1.0)
# Requirement already satisfied: termcolor>=2.5.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (3.1.0)
# Requirement already satisfied: loguru>=0.7.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.7.3)
# Requirement already satisfied: pytest>=8.3.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (8.4.1)
# Requirement already satisfied: pytest-mock>=3.12.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (3.14.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (2.3.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/ec2-user/.local/lib/python3.9/site-packages (from streamlit>=1.39.0->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: jinja2 in /home/ec2-user/.local/lib/python3.9/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.39.0->-r requirements.txt (line 2)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.39.0->-r requirements.txt (line 2)) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/.local/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/.local/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit>=1.39.0->-r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit>=1.39.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit>=1.39.0->-r requirements.txt (line 2)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/.local/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit>=1.39.0->-r requirements.txt (line 2)) (2025.8.3)
# Requirement already satisfied: botocore<1.41.0,>=1.40.6 in /home/ec2-user/.local/lib/python3.9/site-packages (from boto3>=1.35.0->-r requirements.txt (line 6)) (1.40.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/lib/python3.9/site-packages (from boto3>=1.35.0->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from boto3>=1.35.0->-r requirements.txt (line 6)) (0.13.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pdfminer.six==20250506 in /home/ec2-user/.local/lib/python3.9/site-packages (from pdfplumber>=0.11.4->-r requirements.txt (line 12)) (20250506)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from pdfplumber>=0.11.4->-r requirements.txt (line 12)) (4.30.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/lib64/python3.9/site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->-r requirements.txt (line 12)) (36.0.1)
# Requirement already satisfied: chardet in /usr/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (4.0.0)
# Requirement already satisfied: filetype in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: python-magic in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (0.4.27)
# Requirement already satisfied: lxml in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (6.0.0)
# Requirement already satisfied: nltk in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (4.13.4)
# Requirement already satisfied: emoji in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (2.14.1)
# Requirement already satisfied: dataclasses-json in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (0.6.7)
# Requirement already satisfied: python-iso639 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (2025.2.18)
# Requirement already satisfied: langdetect in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: rapidfuzz in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (3.13.0)
# Requirement already satisfied: backoff in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: unstructured-client in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (0.42.3)
# Requirement already satisfied: wrapt in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (1.17.3)
# Requirement already satisfied: tqdm in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (4.67.1)
# Requirement already satisfied: psutil in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (7.0.0)
# Requirement already satisfied: python-oxmsg in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (0.0.2)
# Requirement already satisfied: html5lib in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured->-r requirements.txt (line 14)) (1.1)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.3.4)
# Requirement already satisfied: python-multipart in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.0.20)
# Requirement already satisfied: huggingface-hub in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.34.4)
# Requirement already satisfied: onnx in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.18.0)
# Requirement already satisfied: onnxruntime<1.16 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.15.1)
# Requirement already satisfied: transformers>=4.25.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (4.55.2)
# Requirement already satisfied: coloredlogs in /home/ec2-user/.local/lib/python3.9/site-packages (from onnxruntime<1.16->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/ec2-user/.local/lib/python3.9/site-packages (from onnxruntime<1.16->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (25.2.10)
# Requirement already satisfied: sympy in /home/ec2-user/.local/lib/python3.9/site-packages (from onnxruntime<1.16->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.14.0)
# Requirement already satisfied: Events in /home/ec2-user/.local/lib/python3.9/site-packages (from opensearch-py>=2.7.0->-r requirements.txt (line 26)) (0.5)
# Requirement already satisfied: exceptiongroup>=1 in /home/ec2-user/.local/lib/python3.9/site-packages (from pytest>=8.3.0->-r requirements.txt (line 36)) (1.3.0)
# Requirement already satisfied: iniconfig>=1 in /home/ec2-user/.local/lib/python3.9/site-packages (from pytest>=8.3.0->-r requirements.txt (line 36)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/ec2-user/.local/lib/python3.9/site-packages (from pytest>=8.3.0->-r requirements.txt (line 36)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from pytest>=8.3.0->-r requirements.txt (line 36)) (2.19.2)
# Requirement already satisfied: tomli>=1 in /home/ec2-user/.local/lib/python3.9/site-packages (from pytest>=8.3.0->-r requirements.txt (line 36)) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in /usr/lib64/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->-r requirements.txt (line 12)) (1.14.5)
# Requirement already satisfied: pycparser in /usr/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->-r requirements.txt (line 12)) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.39.0->-r requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: filelock in /home/ec2-user/.local/lib/python3.9/site-packages (from transformers>=4.25.1->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (3.19.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib64/python3.9/site-packages (from transformers>=4.25.1->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/.local/lib/python3.9/site-packages (from transformers>=4.25.1->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (2025.7.34)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ec2-user/.local/lib/python3.9/site-packages (from transformers>=4.25.1->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ec2-user/.local/lib/python3.9/site-packages (from transformers>=4.25.1->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from huggingface-hub->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ec2-user/.local/lib/python3.9/site-packages (from huggingface-hub->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.1.8)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from beautifulsoup4->unstructured->-r requirements.txt (line 14)) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from coloredlogs->onnxruntime<1.16->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from dataclasses-json->unstructured->-r requirements.txt (line 14)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from dataclasses-json->unstructured->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured->-r requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: webencodings in /home/ec2-user/.local/lib/python3.9/site-packages (from html5lib->unstructured->-r requirements.txt (line 14)) (0.5.1)
# Requirement already satisfied: scipy in /home/ec2-user/.local/lib/python3.9/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: iopath in /home/ec2-user/.local/lib/python3.9/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.1.10)
# Requirement already satisfied: torch in /home/ec2-user/.local/lib/python3.9/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (2.8.0)
# Requirement already satisfied: torchvision in /home/ec2-user/.local/lib/python3.9/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.23.0)
# Requirement already satisfied: effdet in /home/ec2-user/.local/lib/python3.9/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: timm>=0.9.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.0.19)
# Requirement already satisfied: pycocotools>=2.0.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ec2-user/.local/lib/python3.9/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (4.9.3)
# Requirement already satisfied: networkx in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/lib/python3.9/site-packages (from triton==3.4.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (59.6.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/.local/lib/python3.9/site-packages (from triton==3.4.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (8.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from sympy->onnxruntime<1.16->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/ec2-user/.local/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (3.23.0)
# Requirement already satisfied: portalocker in /home/ec2-user/.local/lib/python3.9/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference>=0.7.23->-r requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: joblib in /home/ec2-user/.local/lib/python3.9/site-packages (from nltk->unstructured->-r requirements.txt (line 14)) (1.5.1)
# Requirement already satisfied: ply==3.11 in /usr/lib/python3.9/site-packages (from pycparser->cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->-r requirements.txt (line 12)) (3.11)
# Requirement already satisfied: olefile in /home/ec2-user/.local/lib/python3.9/site-packages (from python-oxmsg->unstructured->-r requirements.txt (line 14)) (0.47)
# Requirement already satisfied: aiofiles>=24.1.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 14)) (24.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 14)) (2.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/.local/lib/python3.9/site-packages (from httpcore>=1.0.9->unstructured-client->unstructured->-r requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: anyio in /home/ec2-user/.local/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured->-r requirements.txt (line 14)) (4.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/ec2-user/.local/lib/python3.9/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured->-r requirements.txt (line 14)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/ec2-user/.local/lib/python3.9/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured->-r requirements.txt (line 14)) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/.local/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured->-r requirements.txt (line 14)) (1.3.1)

# %%
import os
# AWS 설정
os.environ['AWS_REGION'] = 'us-west-2'  # Example value
os.environ['AWS_PROFILE'] = 'default'  # Example value

# Bedrock 설정
os.environ['BEDROCK_KNOWLEDGE_BASE_ID'] = 'your-knowledge-base-id'
os.environ['BEDROCK_MODEL_ID'] = 'anthropic.claude-3-7-sonnet-20240620-v1:0'
os.environ['BEDROCK_EMBEDDING_MODEL_ID'] = 'amazon.titan-embed-text-v2:0'
os.environ['BEDROCK_RERANK_MODEL_ID'] = 'cohere.rerank-v3-5:0'

# S3 설정
os.environ['S3_BUCKET_NAME'] = 'your-s3-bucket-name'
os.environ['S3_PREFIX'] = 'documents/'

# 애플리케이션 설정
os.environ['MAX_FILE_SIZE_MB'] = '10'
os.environ['SUPPORTED_FILE_TYPES'] = 'pdf,txt,md,jpg,jpeg,png'

# %%
import boto3
import json
import time
from datetime import datetime
from botocore.exceptions import ClientError

# AWS 클라이언트 초기화
region = 'us-west-2'
session = boto3.Session()

# 계정 ID 가져오기
sts_client = boto3.client('sts')
account_id = sts_client.get_caller_identity()['Account']

s3_client = boto3.client('s3', region_name=region)
bedrock_client = boto3.client('bedrock', region_name=region)
bedrock_agent_client = boto3.client('bedrock-agent', region_name=region)
iam_client = boto3.client('iam', region_name=region)
opensearch_client = boto3.client('opensearchserverless', region_name=region)

print(f"✅ AWS 클라이언트 초기화 완료 (Region: {region})")
# Out:
# ✅ AWS 클라이언트 초기화 완료 (Region: us-west-2)

# %% [markdown]
# ## 2. S3 버킷 생성

# %%
# S3 버킷 이름 설정 (고유해야 함)
import uuid
bucket_suffix = str(uuid.uuid4())[:8]

# 1. 데이터 소스용 버킷 (문서 저장)
data_bucket_name = f"my-rag-chatbot-{bucket_suffix}"

# 2. 멀티모달 저장소용 버킷 (supplementalDataStorageConfiguration)
multimodal_bucket_name = f"multimodal-kb-storage-{bucket_suffix}"

print(f"생성할 데이터 소스 S3 버킷: {data_bucket_name}")
print(f"생성할 멀티모달 저장소 S3 버킷: {multimodal_bucket_name}")
# Out:
# 생성할 데이터 소스 S3 버킷: my-rag-chatbot-5711d275
# 생성할 멀티모달 저장소 S3 버킷: multimodal-kb-storage-5711d275

# %%
def create_s3_buckets(data_bucket_name, multimodal_bucket_name, region='us-west-2'):
    """데이터 소스용과 멀티모달 저장소용 S3 버킷 생성"""
    
    def create_single_bucket(bucket_name, bucket_type):
        """단일 S3 버킷 생성 헬퍼 함수"""
        try:
            # us-west-2 리전에서는 LocationConstraint 필요
            s3_client.create_bucket(
                Bucket=bucket_name,
                CreateBucketConfiguration={'LocationConstraint': region}
            )
            
            # 버킷 버전 관리 활성화
            s3_client.put_bucket_versioning(
                Bucket=bucket_name,
                VersioningConfiguration={'Status': 'Enabled'}
            )
            
            print(f"✅ {bucket_type} S3 버킷 생성 완료: {bucket_name}")
            return True
            
        except ClientError as e:
            error_code = e.response['Error']['Code']
            if error_code == 'BucketAlreadyExists':
                print(f"❌ 버킷 이름이 이미 존재합니다: {bucket_name}")
            elif error_code == 'BucketAlreadyOwnedByYou':
                print(f"⚠️  {bucket_type} 버킷이 이미 존재합니다: {bucket_name}")
                return True
            else:
                print(f"❌ {bucket_type} S3 버킷 생성 오류: {e}")
            return False
    
    # 1. 데이터 소스용 버킷 생성
    data_success = create_single_bucket(data_bucket_name, "데이터 소스용")
    
    # 2. 멀티모달 저장소용 버킷 생성
    multimodal_success = create_single_bucket(multimodal_bucket_name, "멀티모달 저장소용")
    
    return data_success, multimodal_success

# S3 버킷들 생성 실행
data_bucket_success, multimodal_bucket_success = create_s3_buckets(data_bucket_name, multimodal_bucket_name, region)

if data_bucket_success and multimodal_bucket_success:
    print(f"\n🎉 모든 S3 버킷 생성 완료!")
    print(f"📁 데이터 소스 버킷: {data_bucket_name}")
    print(f"🗂️  멀티모달 저장소 버킷: {multimodal_bucket_name}")
else:
    print("⚠️ 일부 버킷 생성에 실패했습니다.")
# Out:
# ✅ 데이터 소스용 S3 버킷 생성 완료: my-rag-chatbot-5711d275
# ✅ 멀티모달 저장소용 S3 버킷 생성 완료: multimodal-kb-storage-5711d275
#
# 🎉 모든 S3 버킷 생성 완료!
# 📁 데이터 소스 버킷: my-rag-chatbot-5711d275
# 🗂️  멀티모달 저장소 버킷: multimodal-kb-storage-5711d275

# %% [markdown]
# ## 4. IAM 역할 생성 (Bedrock Knowledge Base용)

# %%
# IAM 역할 이름
kb_role_name = f"BedrockKnowledgeBaseRole-{bucket_suffix}"

# 신뢰 정책 (Bedrock이 이 역할을 사용할 수 있도록)
trust_policy = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Principal": {
                "Service": "bedrock.amazonaws.com"
            },
            "Action": "sts:AssumeRole"
        }
    ]
}

print(f"생성할 IAM 역할 이름: {kb_role_name}")
# Out:
# 생성할 IAM 역할 이름: BedrockKnowledgeBaseRole-5711d275

# %%
def create_iam_role_for_kb(role_name, data_bucket_name, multimodal_bucket_name, collection_arn):
    """Knowledge Base용 IAM 역할 생성 (2개 S3 버킷 지원)"""
    try:
        # IAM 역할 생성
        response = iam_client.create_role(
            RoleName=role_name,
            AssumeRolePolicyDocument=json.dumps(trust_policy),
            Description='Role for Bedrock Knowledge Base to access S3 and OpenSearch'
        )
        
        role_arn = response['Role']['Arn']
        print(f"✅ IAM 역할 생성 완료: {role_name}")
        print(f"Role ARN: {role_arn}")
        
        # 1. S3 접근 정책
        s3_policy = {
            "Version": "2012-10-17",
            "Statement": [
                {
                    "Effect": "Allow",
                    "Action": [
                        "s3:GetObject",
                        "s3:PutObject",
                        "s3:DeleteObject",
                        "s3:ListBucket"
                    ],
                    "Resource": [
                        f"arn:aws:s3:::{data_bucket_name}",
                        f"arn:aws:s3:::{data_bucket_name}/*",
                        f"arn:aws:s3:::{multimodal_bucket_name}",
                        f"arn:aws:s3:::{multimodal_bucket_name}/*"
                    ]
                }
            ]
        }
        
        iam_client.put_role_policy(
            RoleName=role_name,
            PolicyName='S3AccessPolicy',
            PolicyDocument=json.dumps(s3_policy)
        )
        print("✅ S3 접근 정책 연결 완료")

        # 2. OpenSearch 접근 정책
        opensearch_policy = {
            "Version": "2012-10-17",
            "Statement": [
                {
                    "Effect": "Allow",
                    "Action": [
                        "aoss:APIAccessAll"
                    ],
                    "Resource": [
                        "arn:aws:aoss:us-west-2:*:collection/*"  
                    ]
                }
            ]
        }
        
        iam_client.put_role_policy(
            RoleName=role_name,
            PolicyName='OpenSearchServerlessPolicy',
            PolicyDocument=json.dumps(opensearch_policy)
        )
        print("✅ OpenSearch 접근 정책 연결 완료")
        
        # 3. Foundation Model 정책 (새로 추가)
        fm_policy = {
            "Version": "2012-10-17",
            "Statement": [
                {
                    "Effect": "Allow",
                    "Action": [
                        "bedrock:InvokeModel"
                    ],
                    "Resource": [
                        f"arn:aws:bedrock:{region}::foundation-model/amazon.titan-embed-text-v2:0"
                    ]
                }
            ]
        }
        
        iam_client.put_role_policy(
            RoleName=role_name,
            PolicyName='BedrockFoundationModelPolicy',
            PolicyDocument=json.dumps(fm_policy)
        )
        print("✅ Foundation Model 정책 연결 완료")

        # 4. Rerank 정책 추가
        rerank_policy = {
            "Version": "2012-10-17",
            "Statement": [
                {
                    "Effect": "Allow",
                    "Action": ["bedrock:Rerank"],
                    "Resource": ["*"]
                }
            ]
        }

        iam_client.put_role_policy(
            RoleName=role_name,  # 수정됨
            PolicyName='BedrockRerankPolicy',
            PolicyDocument=json.dumps(rerank_policy)
        )
        print("✅ Rerank 정책 연결 완료")

        # 5. Inference Profile 정책 추가
        inference_policy = {
            "Version": "2012-10-17",
            "Statement": [
                {
                    "Effect": "Allow",
                    "Action": [
                        "bedrock:GetInferenceProfile",
                        "bedrock:InvokeModel"
                    ],
                    "Resource": [
                    f"arn:aws:bedrock:{region}:{account_id}:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0",
                    f"arn:aws:bedrock:{region}:{account_id}:application-inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0",
                    f"arn:aws:bedrock:*::foundation-model/anthropic.claude-3-7-sonnet-20250219-v1:0"
                    ]
                }
            ]
        }

        iam_client.put_role_policy(
            RoleName=role_name,  # 수정됨
            PolicyName='BedrockInferenceProfilePolicy',
            PolicyDocument=json.dumps(inference_policy)
        )
        print("✅ Inference Profile 정책 추가 완료")

        return role_arn

    except ClientError as e:
        if e.response['Error']['Code'] == 'EntityAlreadyExists':
            print(f"⚠️  IAM 역할이 이미 존재합니다: {role_name}")
            response = iam_client.get_role(RoleName=role_name)
            return response['Role']['Arn']
        else:
            print(f"❌ IAM 역할 생성 오류: {e}")
            return None

# IAM 역할 생성 실행 (collection_arn 추가)
kb_role_arn = create_iam_role_for_kb(kb_role_name, data_bucket_name, multimodal_bucket_name, collection_arn)
print(f"\nKnowledge Base Role ARN: {kb_role_arn}")
# Out:
# ✅ IAM 역할 생성 완료: BedrockKnowledgeBaseRole-5711d275
# Role ARN: arn:aws:iam::191629784099:role/BedrockKnowledgeBaseRole-5711d275
# ✅ S3 접근 정책 연결 완료
# ✅ OpenSearch 접근 정책 연결 완료
# ✅ Foundation Model 정책 연결 완료
# ✅ Rerank 정책 연결 완료
# ✅ Inference Profile 정책 추가 완료
#
# Knowledge Base Role ARN: arn:aws:iam::191629784099:role/BedrockKnowledgeBaseRole-5711d275

# %% [markdown]
# ## 3. OpenSearch Serverless 컬렉션과 인덱스 생성

# %%
# OpenSearch Serverless 컬렉션 이름
collection_name = f"my-rag-{bucket_suffix}"

print(f"생성할 OpenSearch Serverless 컬렉션: {collection_name}")
# Out:
# 생성할 OpenSearch Serverless 컬렉션: my-rag-5711d275

# %%
def create_opensearch_collection_and_index(collection_name):
    """OpenSearch Serverless 컬렉션과 벡터 인덱스 생성"""
    
    def create_vector_index(endpoint):
        """벡터 인덱스 생성 헬퍼 함수"""
        from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth
        
        try:
            # AWS 인증 설정
            credentials = boto3.Session().get_credentials()
            auth = AWSV4SignerAuth(credentials, region, 'aoss')
            
            # OpenSearch 클라이언트 생성
            host = endpoint.replace('https://', '')
            client = OpenSearch(
                hosts=[{'host': host, 'port': 443}],
                http_auth=auth,
                use_ssl=True,
                verify_certs=True,
                connection_class=RequestsHttpConnection,
                pool_maxsize=20
            )
            
            # 벡터 인덱스 설정
            index_body = {
                'settings': {
                    'index': {
                        'knn': True,
                        'knn.algo_param.ef_search': 512
                    }
                },
                'mappings': {
                    'properties': {
                        'bedrock-knowledge-base-default-vector': {
                            'type': 'knn_vector',
                            'dimension': 1024,
                            'method': {
                                'name': 'hnsw',
                                'space_type': 'l2',
                                'engine': 'faiss',
                                'parameters': {
                                    'ef_construction': 512,
                                    'm': 16
                                }
                            }
                        },
                        'AMAZON_BEDROCK_TEXT': {
                            'type': 'text',
                            "fields": {
                                "keyword": {
                                  "type": "keyword"
                                }
                  }
                        },
                        'AMAZON_BEDROCK_METADATA': {
                            'type': 'text',
                            'index': False
                        }
                    }
                }
            }
            
            # 인덱스 생성
            response = client.indices.create(
                index='bedrock-knowledge-base-default-index',
                body=index_body
            )
            
            if response.get('acknowledged', False):
                return True
            else:
                print(f'인덱스 생성 실패: {response}')
                return False
                
        except Exception as e:
            print(f'인덱스 생성 중 오류: {e}')
            return False
    
    try:
        # 보안 정책 생성 (암호화)
        encryption_policy = {
            "Rules": [
                {
                    "ResourceType": "collection",
                    "Resource": [f"collection/{collection_name}"]
                }
            ],
            "AWSOwnedKey": True
        }
        
        opensearch_client.create_security_policy(
            name=f"{collection_name}",
            type='encryption',
            policy=json.dumps(encryption_policy)
        )
        
        print("✅ 암호화 정책 생성 완료")
        
        # 네트워크 정책 생성 (퍼블릭 액세스)
        network_policy = [
            {
                "Rules": [
                    {
                        "ResourceType": "collection",
                        "Resource": [f"collection/{collection_name}"]
                    },
                    {
                        "ResourceType": "dashboard",
                        "Resource": [f"collection/{collection_name}"]
                    }
                ],
                "AllowFromPublic": True
            }
        ]
        
        opensearch_client.create_security_policy(
            name=f"{collection_name}-network",
            type='network',
            policy=json.dumps(network_policy)
        )
        
        print("✅ 네트워크 정책 생성 완료")
        
        # 데이터 접근 정책 생성
        data_access_policy = [
            {
                "Rules": [
                    {
                        "ResourceType": "collection",
                        "Resource": [f"collection/{collection_name}"],
                        "Permission": [
                            "aoss:CreateCollectionItems",
                            "aoss:DeleteCollectionItems",
                            "aoss:UpdateCollectionItems",
                            "aoss:DescribeCollectionItems"
                        ]
                    },
                    {
                        "ResourceType": "index",
                        "Resource": [f"index/{collection_name}/*"],
                        "Permission": [
                            "aoss:CreateIndex",
                            "aoss:DeleteIndex",
                            "aoss:UpdateIndex",
                            "aoss:DescribeIndex",
                            "aoss:ReadDocument",
                            "aoss:WriteDocument"
                        ]
                    }
                ],
                "Principal": [kb_role_arn]
            }
        ]
        
        opensearch_client.create_access_policy(
            name=f"{collection_name}-access",
            type='data',
            policy=json.dumps(data_access_policy)
        )
        print("✅ 데이터 접근 정책 생성 완료")

        # 컬렉션 생성
        response = opensearch_client.create_collection(
            name=collection_name,
            type='VECTORSEARCH',
            description='Vector collection for RAG chatbot'
            standbyReplicas='DISABLED'
        )
        
        collection_id = response['createCollectionDetail']['id']
        collection_arn = response['createCollectionDetail']['arn']
        
        print(f"✅ OpenSearch Serverless 컬렉션 생성 시작")
        print(f"Collection ID: {collection_id}")
        print(f"Collection ARN: {collection_arn}")
        
        # 컬렉션 생성 완료 대기
        print("⏳ 컬렉션 생성 완료 대기 중...")
        
        while True:
            response = opensearch_client.list_collections(
                collectionFilters={'name': collection_name}
            )
            
            if response['collectionSummaries']:
                status = response['collectionSummaries'][0]['status']
                print(f"현재 상태: {status}")
                
                if status == 'ACTIVE':
                    detail_response = opensearch_client.batch_get_collection(
                        names=[collection_name]
                    )
                    
                    if detail_response['collectionDetails']:
                        collection_detail = detail_response['collectionDetails'][0]
                        endpoint = collection_detail['collectionEndpoint']
                        
                        print(f"✅ 컬렉션 생성 완료!")
                        print(f"Endpoint: {endpoint}")
                        
                        # 벡터 인덱스 생성
                        print("⏳ 벡터 인덱스 생성 중...")
                        index_created = create_vector_index(endpoint)
                        
                        if index_created:
                            print("✅ 벡터 인덱스 생성 완료!")
                        else:
                            print("⚠️ 벡터 인덱스 생성 실패 (Knowledge Base 생성 시 자동 생성됨)")
                        
                        return collection_id, collection_arn, endpoint
                    else:
                        print("❌ 컬렉션 세부 정보를 가져올 수 없습니다")
                        return collection_id, collection_arn, None
                        
                elif status == 'FAILED':
                    print("❌ 컬렉션 생성 실패")
                    return None, None, None
            
            time.sleep(30)  # 30초 대기
            
    except ClientError as e:
        print(f"❌ OpenSearch Serverless 컬렉션 생성 오류: {e}")
        return None, None, None

# OpenSearch Serverless 컬렉션과 인덱스 생성 실행
collection_id, collection_arn, collection_endpoint = create_opensearch_collection_and_index(collection_name)
# Out:
# ✅ 암호화 정책 생성 완료
# ✅ 네트워크 정책 생성 완료
# ✅ 데이터 접근 정책 생성 완료
# ✅ OpenSearch Serverless 컬렉션 생성 시작
# Collection ID: 15pb1e2mji71kcv0romh
# Collection ARN: arn:aws:aoss:us-west-2:191629784099:collection/15pb1e2mji71kcv0romh
# ⏳ 컬렉션 생성 완료 대기 중...
# 현재 상태: CREATING
# 현재 상태: ACTIVE
# ✅ 컬렉션 생성 완료!
# Endpoint: https://15pb1e2mji71kcv0romh.us-west-2.aoss.amazonaws.com
# ⏳ 벡터 인덱스 생성 중...
# ✅ 벡터 인덱스 생성 완료!

# %% [markdown]
# ## 5. Bedrock Knowledge Base 생성

# %%
# Knowledge Base 이름
kb_name = f"my-rag-kb-{bucket_suffix}"

print(f"생성할 Knowledge Base 이름: {kb_name}")
# Out:
# 생성할 Knowledge Base 이름: my-rag-kb-5711d275

# %%
def create_knowledge_base(kb_name, data_bucket_name, multimodal_bucket_name, collection_arn, role_arn):
    """Bedrock Knowledge Base 생성 (컬렉션과 인덱스 기반)"""
    try:
        response = bedrock_agent_client.create_knowledge_base(
            name=kb_name,
            description='Knowledge Base for RAG chatbot',
            roleArn=role_arn, 
            knowledgeBaseConfiguration={
                'type': 'VECTOR',
                'vectorKnowledgeBaseConfiguration': {
                    'embeddingModelArn': f'arn:aws:bedrock:{region}::foundation-model/amazon.titan-embed-text-v2:0',
                    'embeddingModelConfiguration': {
                        'bedrockEmbeddingModelConfiguration': {
                            'dimensions': 1024,
                            'embeddingDataType': 'FLOAT32'
                        }
                    },
                    'supplementalDataStorageConfiguration': {
                        'storageLocations': [
                            {
                                's3Location': {
                                    'uri': f's3://{multimodal_bucket_name}'
                                },
                                'type': 'S3'
                            }
                        ]
                    }
                }
            },
            storageConfiguration={
                'type': 'OPENSEARCH_SERVERLESS',
                'opensearchServerlessConfiguration': {
                    'collectionArn': collection_arn,
                    'vectorIndexName': 'bedrock-knowledge-base-default-index',
                    'fieldMapping': {
                        'vectorField': 'bedrock-knowledge-base-default-vector',
                        'textField': 'AMAZON_BEDROCK_TEXT',
                        'metadataField': 'AMAZON_BEDROCK_METADATA'
                    }
                }
            }
        )
        
        kb_id = response['knowledgeBase']['knowledgeBaseId']
        kb_arn = response['knowledgeBase']['knowledgeBaseArn']
        
        print(f"✅ Knowledge Base 생성 완료!")
        print(f"Knowledge Base ID: {kb_id}")
        print(f"Knowledge Base ARN: {kb_arn}")
        
        return kb_id, kb_arn
        
    except ClientError as e:
        print(f"❌ Knowledge Base 생성 오류: {e}")
        # 이미 존재하는 경우 기존 KB 정보 조회
        if 'already exists' in str(e):
            print("🔍 기존 Knowledge Base 정보를 조회합니다...")
            try:
                kb_list = bedrock_agent_client.list_knowledge_bases()
                for kb in kb_list['knowledgeBaseSummaries']:
                    if kb['name'] == kb_name:
                        existing_kb_id = kb['knowledgeBaseId']
                        kb_detail = bedrock_agent_client.get_knowledge_base(knowledgeBaseId=existing_kb_id)
                        existing_kb_arn = kb_detail['knowledgeBase']['knowledgeBaseArn']
                        print(f"✅ 기존 Knowledge Base 사용: {existing_kb_id}")
                        return existing_kb_id, existing_kb_arn
            except Exception as lookup_error:
                print(f"❌ 기존 Knowledge Base 조회 오류: {lookup_error}")
        return None, None

# Knowledge Base 생성 (컬렉션과 인덱스가 준비된 경우에만)
if collection_arn and collection_endpoint:
    print("\n🚀 Knowledge Base 생성 시작...")
    kb_id, kb_arn = create_knowledge_base(kb_name, data_bucket_name, multimodal_bucket_name, collection_arn, kb_role_arn)
else:
    print("❌ OpenSearch 컬렉션과 인덱스가 준비되지 않아 Knowledge Base를 생성할 수 없습니다.")
    kb_id, kb_arn = None, None

print(f"✅ Knowledge Base ID: {kb_id}")  # 이 줄이 있어야 함
# Out:
# 🚀 Knowledge Base 생성 시작...
# ❌ Knowledge Base 생성 오류: An error occurred (ConflictException) when calling the CreateKnowledgeBase operation: KnowledgeBase with name my-rag-kb-5711d275 already exists.
# 🔍 기존 Knowledge Base 정보를 조회합니다...
# ✅ 기존 Knowledge Base 사용: SVJFXS8QCG
# ✅ Knowledge Base ID: SVJFXS8QCG

# %% [markdown]
# ## 6. 데이터 소스 생성 (S3 연결)

# %%
def create_data_source(kb_id, data_bucket_name):
    """Knowledge Base에 S3 데이터 소스 연결"""
    try:
        response = bedrock_agent_client.create_data_source(
            knowledgeBaseId=kb_id,
            name=f"multimodal-data-source-{bucket_suffix}",
            description='Multimodal S3 data source with Claude parsing',
            dataSourceConfiguration={
                'type': 'S3',
                's3Configuration': {
                    'bucketArn': f'arn:aws:s3:::{data_bucket_name}',
                    'inclusionPrefixes': ['documents/']
                }
            },
            vectorIngestionConfiguration={
                'chunkingConfiguration': {
                    'chunkingStrategy': 'HIERARCHICAL',
                    'hierarchicalChunkingConfiguration': {
                        'levelConfigurations': [
                            {
                                'maxTokens': 1500
                            },
                            {
                                'maxTokens': 300
                            }
                        ],
                        'overlapTokens': 60
                    }
                },
                'parsingConfiguration': {
                    'parsingStrategy': 'BEDROCK_FOUNDATION_MODEL',
                    'bedrockFoundationModelConfiguration': {
                        'modelArn': f'arn:aws:bedrock:{region}:{account_id}:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0',
                        'parsingModality': 'MULTIMODAL'
                    }
                }
            }
        )
        
        data_source_id = response['dataSource']['dataSourceId']
        
        print(f"✅ 데이터 소스 생성 완료!")
        print(f"Data Source ID: {data_source_id}")
        
        return data_source_id
        
    except ClientError as e:
        print(f"❌ 데이터 소스 생성 오류: {e}")
        return None

# 데이터 소스 생성 실행
if kb_id:
    data_source_id = create_data_source(kb_id, data_bucket_name)
else:
    print("❌ Knowledge Base가 준비되지 않아 데이터 소스를 생성할 수 없습니다.")
    data_source_id = None
# Out:
# ✅ 데이터 소스 생성 완료!
# Data Source ID: VMDVQHKIM1

# %% [markdown]
# ## 7. 생성된 리소스 정보 요약

# %%
print("🎉 AWS 멀티모달 RAG 리소스 생성 완료!")
print("=" * 60)

print("📦 S3 버킷들:")
print(f"   - 데이터 소스: {data_bucket_name}")
print(f"   - 멀티모달 저장소: {multimodal_bucket_name}")

print(f"\n🔍 OpenSearch Serverless:")
print(f"   - 컬렉션: {collection_name}")
if collection_endpoint:
    print(f"   - Endpoint: {collection_endpoint}")
print(f"   - 벡터 인덱스: bedrock-knowledge-base-default-index")
print(f"   - 암호화 정책: {collection_name}")
print(f"   - 네트워크 정책: {collection_name}-network")
print(f"   - 데이터 접근 정책: {collection_name}-access")

print(f"\n🧠 Bedrock Knowledge Base:")
print(f"   - 이름: {kb_name}")
if kb_id:
    print(f"   - ID: {kb_id}")
print(f"   - 임베딩 모델: Titan Text v2 (1024차원, FLOAT32)")
print(f"   - 멀티모달 지원: 활성화")

if data_source_id:
    print(f"\n📁 데이터 소스:")
    print(f"   - ID: {data_source_id}")
    print(f"   - 파싱: Claude 3.7 Sonnet (멀티모달)")
    print(f"   - 청킹: 계층형 (1500→300 토큰, 60 오버랩)")

print(f"\n👤 IAM 역할: {kb_role_name}")
print(f"   - S3 접근: 2개 버킷 (읽기/쓰기)")
print(f"   - OpenSearch 접근: 전체 권한")
print(f"   - Bedrock 모델: Titan, Claude, Rerank")

print("\n📝 환경 변수 업데이트 정보:")
print(f"S3_BUCKET_NAME={data_bucket_name}")
print(f"MULTIMODAL_BUCKET_NAME={multimodal_bucket_name}")
if kb_id:
    print(f"BEDROCK_KNOWLEDGE_BASE_ID={kb_id}")
if collection_name:
    print(f"OPENSEARCH_COLLECTION_NAME={collection_name}")
print(f"BEDROCK_MODEL_ID=anthropic.claude-3-7-sonnet-20250219-v1:0")
print(f"BEDROCK_EMBEDDING_MODEL_ID=amazon.titan-embed-text-v2:0")
# Out:
# 🎉 AWS 멀티모달 RAG 리소스 생성 완료!
# ============================================================
# 📦 S3 버킷들:
#    - 데이터 소스: my-rag-chatbot-5711d275
#    - 멀티모달 저장소: multimodal-kb-storage-5711d275
#
# 🔍 OpenSearch Serverless:
#    - 컬렉션: my-rag-5711d275
#    - Endpoint: https://15pb1e2mji71kcv0romh.us-west-2.aoss.amazonaws.com
#    - 벡터 인덱스: bedrock-knowledge-base-default-index
#    - 암호화 정책: my-rag-5711d275
#    - 네트워크 정책: my-rag-5711d275-network
#    - 데이터 접근 정책: my-rag-5711d275-access
#
# 🧠 Bedrock Knowledge Base:
#    - 이름: my-rag-kb-5711d275
#    - ID: SVJFXS8QCG
#    - 임베딩 모델: Titan Text v2 (1024차원, FLOAT32)
#    - 멀티모달 지원: 활성화
#
# 📁 데이터 소스:
#    - ID: VMDVQHKIM1
#    - 파싱: Claude 3.7 Sonnet (멀티모달)
#    - 청킹: 계층형 (1500→300 토큰, 60 오버랩)
#
# 👤 IAM 역할: BedrockKnowledgeBaseRole-5711d275
#    - S3 접근: 2개 버킷 (읽기/쓰기)
#    - OpenSearch 접근: 전체 권한
#    - Bedrock 모델: Titan, Claude, Rerank
#
# 📝 환경 변수 업데이트 정보:
# S3_BUCKET_NAME=my-rag-chatbot-5711d275
# MULTIMODAL_BUCKET_NAME=multimodal-kb-storage-5711d275
# BEDROCK_KNOWLEDGE_BASE_ID=SVJFXS8QCG
# OPENSEARCH_COLLECTION_NAME=my-rag-5711d275
# BEDROCK_MODEL_ID=anthropic.claude-3-7-sonnet-20250219-v1:0
# BEDROCK_EMBEDDING_MODEL_ID=amazon.titan-embed-text-v2:0

# %% [markdown]
# ## 8. 환경 변수 자동 업데이트

# %%
import os

# 환경 변수 업데이트
if data_bucket_name:
    os.environ['S3_BUCKET_NAME'] = data_bucket_name
    print(f"✅ S3_BUCKET_NAME 업데이트: {data_bucket_name}")

if multimodal_bucket_name:
    os.environ['MULTIMODAL_BUCKET_NAME'] = multimodal_bucket_name
    print(f"✅ MULTIMODAL_BUCKET_NAME 업데이트: {multimodal_bucket_name}")

if kb_id:
    os.environ['BEDROCK_KNOWLEDGE_BASE_ID'] = kb_id
    print(f"✅ BEDROCK_KNOWLEDGE_BASE_ID 업데이트: {kb_id}")

if collection_name:
    os.environ['OPENSEARCH_COLLECTION_NAME'] = collection_name
    print(f"✅ OPENSEARCH_COLLECTION_NAME 업데이트: {collection_name}")

if data_source_id:
    os.environ['BEDROCK_DATA_SOURCE_ID'] = data_source_id
    print(f"✅ BEDROCK_DATA_SOURCE_ID 업데이트: {data_source_id}")

# Bedrock 모델 설정
os.environ['BEDROCK_MODEL_ID'] = 'anthropic.claude-3-7-sonnet-20250219-v1:0'
os.environ['BEDROCK_EMBEDDING_MODEL_ID'] = 'amazon.titan-embed-text-v2:0'
os.environ['BEDROCK_RERANK_MODEL_ID'] = 'cohere.rerank-v3-5:0'
print(f"✅ BEDROCK_MODEL_ID 업데이트: Claude 3.7 Sonnet")
print(f"✅ BEDROCK_EMBEDDING_MODEL_ID 업데이트: Titan Text v2")
print(f"✅ BEDROCK_RERANK_MODEL_ID 업데이트: Cohere Rerank v3")

# 애플리케이션 설정
os.environ['AWS_REGION'] = region
os.environ['AWS_ACCOUNT_ID'] = account_id
os.environ['MAX_FILE_SIZE_MB'] = '10'
os.environ['SUPPORTED_FILE_TYPES'] = 'pdf,txt,md,jpg,jpeg,png'
print(f"✅ AWS_REGION 업데이트: {region}")
print(f"✅ AWS_ACCOUNT_ID 업데이트: {account_id}")
print(f"✅ 애플리케이션 설정 업데이트 완료")

# .env 파일 생성
env_content = f'''# AWS 설정
AWS_REGION={region}
AWS_PROFILE=default
AWS_ACCOUNT_ID={account_id}

# S3 설정
S3_BUCKET_NAME={data_bucket_name if data_bucket_name else 'your-data-bucket'}
MULTIMODAL_BUCKET_NAME={multimodal_bucket_name if multimodal_bucket_name else 'your-multimodal-bucket'}
S3_PREFIX=documents/

# Bedrock 설정
BEDROCK_KNOWLEDGE_BASE_ID={kb_id if kb_id else 'your-knowledge-base-id'}
BEDROCK_DATA_SOURCE_ID={data_source_id if data_source_id else 'your-data-source-id'}
BEDROCK_MODEL_ID=anthropic.claude-3-7-sonnet-20250219-v1:0
BEDROCK_EMBEDDING_MODEL_ID=amazon.titan-embed-text-v2:0
BEDROCK_RERANK_MODEL_ID=cohere.rerank-v3-5:0

# OpenSearch 설정
OPENSEARCH_COLLECTION_NAME={collection_name if collection_name else 'your-collection-name'}

# 애플리케이션 설정
MAX_FILE_SIZE_MB=10
SUPPORTED_FILE_TYPES=pdf,txt,md,jpg,jpeg,png
'''

# .env 파일 저장
try:
    with open('.env', 'w', encoding='utf-8') as f:
        f.write(env_content)
    print(f"\n📄 .env 파일 생성 완료!")
    print(f"   위치: {os.path.abspath('.env')}")
    print(f"   내용: 모든 환경 변수가 저장되었습니다")
except Exception as e:
    print(f"\n❌ .env 파일 생성 실패: {e}")

print("\n🎯 다음 단계:")
print("1. S3 버킷들에 문서 업로드 (텍스트, 이미지, PDF)")
print("2. Knowledge Base 데이터 소스 동기화")
print("3. 멀티모달 RAG 챗봇 코드 구현 시작")
print("4. Streamlit UI 개발")
print("\n💡 팁: 생성된 .env 파일을 확인하고 필요시 수정하세요!")
print("⚠️  주의: .env 파일을 Git에 커밋하지 마세요 (.gitignore에 추가됨)")
# Out:
# ✅ S3_BUCKET_NAME 업데이트: my-rag-chatbot-5711d275
# ✅ MULTIMODAL_BUCKET_NAME 업데이트: multimodal-kb-storage-5711d275
# ✅ BEDROCK_KNOWLEDGE_BASE_ID 업데이트: SVJFXS8QCG
# ✅ OPENSEARCH_COLLECTION_NAME 업데이트: my-rag-5711d275
# ✅ BEDROCK_DATA_SOURCE_ID 업데이트: VMDVQHKIM1
# ✅ BEDROCK_MODEL_ID 업데이트: Claude 3.7 Sonnet
# ✅ BEDROCK_EMBEDDING_MODEL_ID 업데이트: Titan Text v2
# ✅ BEDROCK_RERANK_MODEL_ID 업데이트: Cohere Rerank v3
# ✅ AWS_REGION 업데이트: us-west-2
# ✅ AWS_ACCOUNT_ID 업데이트: 191629784099
# ✅ 애플리케이션 설정 업데이트 완료
#
# 📄 .env 파일 생성 완료!
#    위치: /home/ec2-user/workshop/my-rag-chatbot-2/.env
#    내용: 모든 환경 변수가 저장되었습니다
#
# 🎯 다음 단계:
# 1. S3 버킷들에 문서 업로드 (텍스트, 이미지, PDF)
# 2. Knowledge Base 데이터 소스 동기화
# 3. 멀티모달 RAG 챗봇 코드 구현 시작
# 4. Streamlit UI 개발
#
# 💡 팁: 생성된 .env 파일을 확인하고 필요시 수정하세요!
# ⚠️  주의: .env 파일을 Git에 커밋하지 마세요 (.gitignore에 추가됨)
